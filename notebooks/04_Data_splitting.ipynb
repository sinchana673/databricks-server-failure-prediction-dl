# %%
display(spark.read.table('workspace.server_failure.server_failure_features'))

# %%
display(spark.read.table('workspace.server_failure.server_failure_features_gold'))

# %%
display(spark.read.table('workspace.server_failure.server_metrics_bronze'))

# %%
display(spark.read.table('workspace.server_failure.server_metrics_silver'))
